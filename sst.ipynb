# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Crime.csv")
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9835     Lakshadweep    LAKSHADWEEP  2013       0                  0
# 9836     Lakshadweep       ZZ TOTAL  2013       0                  0
# 9837      Puducherry       KARAIKAL  2013       6                  3
# 9838      Puducherry     PUDUCHERRY  2013      25                  8
# 9839      Puducherry       ZZ TOTAL  2013      31                 11
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df=pd.read_csv("Crime.csv")

# %%
df.drop('CRIMINAL BREACH OF TRUST',axis=1,inplace=True)
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9835     Lakshadweep    LAKSHADWEEP  2013       0                  0
# 9836     Lakshadweep       ZZ TOTAL  2013       0                  0
# 9837      Puducherry       KARAIKAL  2013       6                  3
# 9838      Puducherry     PUDUCHERRY  2013      25                  8
# 9839      Puducherry       ZZ TOTAL  2013      31                 11
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CHEATING', 'COUNTERFIETING',
#        'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df["CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"].unique()
# Out:
# array([  17,    1,    2,    0,    7,    6,    4,   26,   12,    5,   14,
#           3,   16,  136,    8,   40,   20,   11,   21,   18,   30,   10,
#           9,   13,  250,   45,   60,   94,   78,   33,   53,  143,   74,
#         111,   27,   28,  125,  101,   80,   63,   19,   23,   24,   15,
#          25,   29,   36,   22,   37,   56, 1186,   38,   61,   75,   43,
#          34,   44,  581,   31,  165,   55,   92,  396,   89,  115,   59,
#          42,  210,   97,  194,   93,   58,   79,   68,   35, 1243,   47,
#          62,   54,   32,  540,  147,   48,  298,   51,   76,  109,  343,
#         203,  113,  138,  188,   39,   46, 1525,   50,  484,   65,  163,
#         280,   57,  148,  473,   41, 1436,  468,   71,  117,  259,   87,
#          88,  134,   98,   73,  216, 1520,  408,   64,  123,   83,  326,
#         100, 1543,  401,  135,  257,   72,  155,  170, 1616,  394,  386,
#         112,   81,   95,  204,   84,  146, 1493,  488,   66,  243,  104,
# ...

# %%
df.drop('CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER', 'RAPE',
#        'CUSTODIAL RAPE', 'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CHEATING', 'COUNTERFIETING',
#        'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df.drop('CAUSING DEATH BY NEGLIGENCE',axis=1,inplace=True)

# %%
df.drop('ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER', 'RAPE',
#        'CUSTODIAL RAPE', 'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY', 'ROBBERY', 'BURGLARY',
#        'THEFT', 'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CHEATING',
#        'COUNTERFIETING', 'ARSON', 'DOWRY DEATHS', 'INSULT TO MODESTY OF WOMEN',
#        'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES', 'OTHER IPC CRIMES',
#        'TOTAL IPC CRIMES'],
#       dtype='object')
